# %%
import numpy as np
import pandas as pd

# %%
label_dict = {
     "2149051_送风温度001": ["2157538_冷通道温度","2157537_冷通道温度","2157536_冷通道温度", '2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度'],
     "2149061_送风温度001": ["2157538_冷通道温度","2157537_冷通道温度","2157536_冷通道温度", '2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度'],

     "2149052_送风温度001": ["2157538_冷通道温度","2157537_冷通道温度","2157536_冷通道温度", '2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度'],
     "2149062_送风温度001": ["2157538_冷通道温度","2157537_冷通道温度","2157536_冷通道温度", '2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度'],
     "2149053_送风温度001": ["2157538_冷通道温度","2157537_冷通道温度","2157536_冷通道温度", '2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度'],
     "2149063_送风温度001": ["2157538_冷通道温度","2157537_冷通道温度","2157536_冷通道温度", '2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度'],
    
     "2149054_送风温度001": ['2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度', '2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度'],
     "2149064_送风温度001": ['2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度', '2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度'],
     "2149055_送风温度001": ['2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度', '2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度'],
     "2149065_送风温度001": ['2157535_冷通道温度','2157534_冷通道温度','2157533_冷通道温度', '2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度'],
    
     "2149056_送风温度001": ['2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度', '2157529_冷通道温度','2157528_冷通道温度','2157527_冷通道温度'],
     "2149066_送风温度001": ['2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度', '2157529_冷通道温度','2157528_冷通道温度','2157527_冷通道温度'],
     "2149057_送风温度001": ['2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度', '2157529_冷通道温度','2157528_冷通道温度','2157527_冷通道温度'],
     "2149067_送风温度001": ['2157532_冷通道温度','2157531_冷通道温度','2157530_冷通道温度', '2157529_冷通道温度','2157528_冷通道温度','2157527_冷通道温度'],
    
     "2149058_送风温度001": ['2157526_冷通道温度','2157525_冷通道温度','2157524_冷通道温度','2157523_冷通道温度','2157522_冷通道温度','2157521_冷通道温度'],
     "2149068_送风温度001": ['2157526_冷通道温度','2157525_冷通道温度','2157524_冷通道温度','2157523_冷通道温度','2157522_冷通道温度','2157521_冷通道温度'],
     "2149059_送风温度001": ['2157526_冷通道温度','2157525_冷通道温度','2157524_冷通道温度','2157523_冷通道温度','2157522_冷通道温度','2157521_冷通道温度'],
     "2149069_送风温度001": ['2157526_冷通道温度','2157525_冷通道温度','2157524_冷通道温度','2157523_冷通道温度','2157522_冷通道温度','2157521_冷通道温度'],
 
     "2149060_送风温度001": ['2157526_冷通道温度','2157525_冷通道温度','2157524_冷通道温度','2157523_冷通道温度','2157522_冷通道温度','2157521_冷通道温度'],
     "2149070_送风温度001": ['2157526_冷通道温度','2157525_冷通道温度','2157524_冷通道温度','2157523_冷通道温度','2157522_冷通道温度','2157521_冷通道温度']

}

# %%
import pandas as pd

# 创建一个空的dataframe
df = pd.DataFrame()

# 遍历dict的每个key和value
for key, value in label_dict.items():
    # 将value转化为set，去除重复的字符串
    value_set = set(value)
    # 将value_set中的每个字符串作为列名，value_set与key的交集作为对应的值
    for col in value_set:
        df.loc[key, col] = 1

# 将缺失值用空字符串填充
df = df.fillna(0)

# %%
df
# Out:
#                  2157534_冷通道温度  2157538_冷通道温度  2157535_冷通道温度  2157536_冷通道温度  \
# 2149051_送风温度001            1.0            1.0            1.0            1.0
# 2149061_送风温度001            1.0            1.0            1.0            1.0
# 2149052_送风温度001            1.0            1.0            1.0            1.0
# 2149062_送风温度001            1.0            1.0            1.0            1.0
# 2149053_送风温度001            1.0            1.0            1.0            1.0
# 2149063_送风温度001            1.0            1.0            1.0            1.0
# 2149054_送风温度001            1.0            0.0            1.0            0.0
# 2149064_送风温度001            1.0            0.0            1.0            0.0
# 2149055_送风温度001            1.0            0.0            1.0            0.0
# 2149065_送风温度001            1.0            0.0            1.0            0.0
# 2149056_送风温度001            0.0            0.0            0.0            0.0
# ...

# %%
df.to_csv('air2cold_label.csv')
