# %%
# Imports
import numpy as np
from matplotlib import pyplot as plt
# %matplotlib inline     

from tigramite import data_processing as pp
from tigramite.pcmci import PCMCI
from tigramite.independence_tests import ParCorr

# %%
graph = '5_p1_smp3000' # 10_p1_smp5500, downstream
if graph == '5_p1_smp3000':
    num_nodes = 5
    data = 'simu'
elif graph == '10_p1_smp5500':
    num_nodes = 10
    data = 'simu'
elif graph == 'downstream':
    num_nodes = 38
    data = 'real'

for i in range(1,11):
    file_name = 'data'+str(i)+'.npy'
    path = f'/home/lipeiwen.lpw/TECDI/data_{data}/{graph}/'+file_name
    data1 = np.load(path)
    data1 = data1[:,0:num_nodes]
    # 检查每一列是否都一样
    col_equal = [np.allclose(data1[:, i], data1[0, i]) for i in range(data1.shape[1])]

    # 删除重复列
    data1 = np.delete(data1, np.where(col_equal)[0], axis=1)
    col_num = data1.shape[1]
    # mean = np.mean(data1)
    # std = np.std(data1)
    # data = (data1 - mean) / std
    dataframe = pp.DataFrame(data1)
    parcorr = ParCorr()
    pcmci_parcorr = PCMCI(
    dataframe=dataframe, 
    cond_ind_test=parcorr,
    verbosity=1)
    results = pcmci_parcorr.run_pcmci(tau_max=2, pc_alpha=0.2)
    pcmci_parcorr.print_significant_links(
    p_matrix = results['p_matrix'], 
        val_matrix = results['val_matrix'],
        alpha_level = 0.01)
    link_matrix = pcmci_parcorr.return_significant_parents(pq_matrix=results['p_matrix'],
                        val_matrix=results['val_matrix'], alpha_level=0.01)['link_matrix']
    result_mat = np.zeros([col_num*2,col_num*2])
    result_mat[0:col_num,0:col_num] = link_matrix[:,:,0]+0
    result_mat[col_num:col_num*2,0:col_num] = link_matrix[:,:,1]+0
    np.save(f'../baseline_results/{graph}/PCMCI_est{i}',result_mat)
# Out:
# ##
# ## Running Tigramite PC algorithm
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 2
# pc_alpha = 0.2
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable 0
#
# ## Variable 1
#
# ## Variable 2
#
# ## Variable 3
#
# ## Variable 4
#
# ## Resulting condition sets:
#
#     Variable 0 has 4 parent(s):
#         (4 -1): max_pval = 0.00000, min_val = 0.527
#         (3 -1): max_pval = 0.00000, min_val = 0.457
#         (2 -2): max_pval = 0.00001, min_val = 0.081
#         (2 -1): max_pval = 0.03244, min_val = 0.039
#
#     Variable 1 has 4 parent(s):
#         (4 -1): max_pval = 0.00000, min_val = 0.348
#         (3 -1): max_pval = 0.00000, min_val = 0.330
#         (2 -1): max_pval = 0.00000, min_val = 0.288
#         (1 -2): max_pval = 0.14140, min_val = 0.027
#
#     Variable 2 has 4 parent(s):
#         (4 -1): max_pval = 0.00000, min_val = 0.140
#         (3 -1): max_pval = 0.00000, min_val = 0.129
#         (2 -1): max_pval = 0.00000, min_val = 0.111
#         (0 -1): max_pval = 0.15215, min_val = 0.026
#
#     Variable 3 has 4 parent(s):
#         (2 -1): max_pval = 0.00000, min_val = 0.514
#         (3 -1): max_pval = 0.00000, min_val = 0.238
#         (4 -1): max_pval = 0.00001, min_val = 0.079
#         (1 -1): max_pval = 0.00007, min_val = 0.073
#
#     Variable 4 has 2 parent(s):
#         (2 -1): max_pval = 0.00000, min_val = 0.570
#         (4 -1): max_pval = 0.00000, min_val = 0.354
#
# ##
# ## Running Tigramite MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 2
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 7 link(s):
#         (1 0): pval = 0.00000 | val = 0.561 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = 0.525 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = -0.496 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = -0.449 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = -0.448 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = 0.200 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = -0.111 | conf = (0.000, 0.000)
#
#     Variable 1 has 7 link(s):
#         (0 0): pval = 0.00000 | val = 0.561 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = 0.430 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = 0.258 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = -0.253 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = 0.253 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = -0.242 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = 0.111 | conf = (0.000, 0.000)
#
#     Variable 2 has 8 link(s):
#         (4 -1): pval = 0.00000 | val = -0.350 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = -0.315 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = -0.258 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = 0.255 | conf = (0.000, 0.000)
#         (1 0): pval = 0.00000 | val = 0.253 | conf = (0.000, 0.000)
#         (0 0): pval = 0.00000 | val = 0.200 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = -0.112 | conf = (0.000, 0.000)
#         (0 -1): pval = 0.02622 | val = 0.041 | conf = (0.000, 0.000)
#
#     Variable 3 has 6 link(s):
#         (2 -1): pval = 0.00000 | val = -0.535 | conf = (0.000, 0.000)
#         (0 0): pval = 0.00000 | val = 0.525 | conf = (0.000, 0.000)
#         (1 0): pval = 0.00000 | val = 0.430 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = -0.430 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = 0.283 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = -0.258 | conf = (0.000, 0.000)
#
#     Variable 4 has 5 link(s):
#         (2 -1): pval = 0.00000 | val = -0.502 | conf = (0.000, 0.000)
#         (0 0): pval = 0.00000 | val = -0.449 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = 0.368 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = -0.315 | conf = (0.000, 0.000)
#         (1 0): pval = 0.00000 | val = 0.111 | conf = (0.000, 0.000)
#
# ## Significant links at alpha = 0.01:
#
#     Variable 0 has 7 link(s):
#         (1 0): pval = 0.00000 | val = 0.561
#         (3 0): pval = 0.00000 | val = 0.525
#         (4 -1): pval = 0.00000 | val = -0.496
#         (4 0): pval = 0.00000 | val = -0.449
#         (3 -1): pval = 0.00000 | val = -0.448
#         (2 0): pval = 0.00000 | val = 0.200
#         (2 -1): pval = 0.00000 | val = -0.111
#
#     Variable 1 has 7 link(s):
#         (0 0): pval = 0.00000 | val = 0.561
#         (3 0): pval = 0.00000 | val = 0.430
#         (2 -1): pval = 0.00000 | val = 0.258
#         (4 -1): pval = 0.00000 | val = -0.253
#         (2 0): pval = 0.00000 | val = 0.253
#         (3 -1): pval = 0.00000 | val = -0.242
#         (4 0): pval = 0.00000 | val = 0.111
#
#     Variable 2 has 7 link(s):
#         (4 -1): pval = 0.00000 | val = -0.350
#         (4 0): pval = 0.00000 | val = -0.315
#         (3 0): pval = 0.00000 | val = -0.258
#         (3 -1): pval = 0.00000 | val = 0.255
#         (1 0): pval = 0.00000 | val = 0.253
#         (0 0): pval = 0.00000 | val = 0.200
#         (2 -1): pval = 0.00000 | val = -0.112
#
#     Variable 3 has 6 link(s):
#         (2 -1): pval = 0.00000 | val = -0.535
#         (0 0): pval = 0.00000 | val = 0.525
#         (1 0): pval = 0.00000 | val = 0.430
#         (3 -1): pval = 0.00000 | val = -0.430
#         (4 -1): pval = 0.00000 | val = 0.283
#         (2 0): pval = 0.00000 | val = -0.258
#
#     Variable 4 has 5 link(s):
#         (2 -1): pval = 0.00000 | val = -0.502
#         (0 0): pval = 0.00000 | val = -0.449
#         (4 -1): pval = 0.00000 | val = 0.368
#         (2 0): pval = 0.00000 | val = -0.315
#         (1 0): pval = 0.00000 | val = 0.111
#
# ##
# ## Running Tigramite PC algorithm
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 2
# pc_alpha = 0.2
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable 0
#
# ## Variable 1
#
# ## Variable 2
#
# ## Variable 3
#
# ## Variable 4
#
# ## Resulting condition sets:
#
#     Variable 0 has 5 parent(s):
#         (1 -1): max_pval = 0.00000, min_val = 0.497
#         (2 -1): max_pval = 0.00000, min_val = 0.248
#         (2 -2): max_pval = 0.00000, min_val = 0.116
#         (3 -2): max_pval = 0.00000, min_val = 0.091
#         (0 -1): max_pval = 0.00000, min_val = 0.087
#
#     Variable 1 has 5 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.405
#         (2 -1): max_pval = 0.00000, min_val = 0.265
#         (4 -1): max_pval = 0.00000, min_val = 0.089
#         (1 -1): max_pval = 0.00169, min_val = 0.057
#         (0 -1): max_pval = 0.19457, min_val = 0.024
#
#     Variable 2 has 7 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.210
#         (4 -2): max_pval = 0.00028, min_val = 0.066
#         (1 -2): max_pval = 0.00104, min_val = 0.060
#         (3 -2): max_pval = 0.01359, min_val = 0.045
#         (2 -1): max_pval = 0.06428, min_val = 0.034
#         (0 -1): max_pval = 0.08515, min_val = 0.031
#         (1 -1): max_pval = 0.10391, min_val = 0.030
#
#     Variable 3 has 6 parent(s):
#         (2 -1): max_pval = 0.00000, min_val = 0.441
#         (3 -1): max_pval = 0.00000, min_val = 0.242
#         (1 -2): max_pval = 0.00002, min_val = 0.079
#         (2 -2): max_pval = 0.00002, min_val = 0.079
#         (4 -1): max_pval = 0.00015, min_val = 0.069
#         (4 -2): max_pval = 0.03756, min_val = 0.038
#
#     Variable 4 has 6 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.534
#         (1 -1): max_pval = 0.00000, min_val = 0.336
#         (1 -2): max_pval = 0.01683, min_val = 0.044
#         (2 -1): max_pval = 0.03308, min_val = 0.039
#         (3 -2): max_pval = 0.06706, min_val = 0.033
#         (4 -2): max_pval = 0.07606, min_val = 0.032
#
# ##
# ## Running Tigramite MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 2
# max_conds_py = None
# max_conds_px = None
#
# ## Significant links at alpha = 0.05:
#
#     Variable 0 has 13 link(s):
#         (1 0): pval = 0.00000 | val = 0.697 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = -0.560 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = 0.470 | conf = (0.000, 0.000)
#         (1 -1): pval = 0.00000 | val = -0.429 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = -0.348 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = 0.246 | conf = (0.000, 0.000)
#         (0 -1): pval = 0.00000 | val = -0.183 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = 0.153 | conf = (0.000, 0.000)
#         (1 -2): pval = 0.00000 | val = -0.123 | conf = (0.000, 0.000)
#         (3 -2): pval = 0.00008 | val = 0.072 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00042 | val = 0.064 | conf = (0.000, 0.000)
#         (0 -2): pval = 0.00279 | val = -0.055 | conf = (0.000, 0.000)
#         (2 -2): pval = 0.00378 | val = 0.053 | conf = (0.000, 0.000)
#
#     Variable 1 has 9 link(s):
#         (0 0): pval = 0.00000 | val = 0.697 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = -0.587 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = 0.541 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = 0.454 | conf = (0.000, 0.000)
#         (0 -1): pval = 0.00000 | val = -0.361 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = 0.318 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = -0.195 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = 0.103 | conf = (0.000, 0.000)
#         (1 -1): pval = 0.00202 | val = 0.056 | conf = (0.000, 0.000)
#
#     Variable 2 has 13 link(s):
#         (0 -1): pval = 0.00000 | val = -0.490 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = -0.393 | conf = (0.000, 0.000)
#         (1 -1): pval = 0.00000 | val = 0.266 | conf = (0.000, 0.000)
#         (0 0): pval = 0.00000 | val = 0.246 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = -0.240 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = 0.140 | conf = (0.000, 0.000)
#         (1 -2): pval = 0.00000 | val = -0.117 | conf = (0.000, 0.000)
#         (1 0): pval = 0.00000 | val = 0.103 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = 0.101 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00010 | val = -0.071 | conf = (0.000, 0.000)
#         (3 -2): pval = 0.00164 | val = 0.058 | conf = (0.000, 0.000)
#         (0 -2): pval = 0.00386 | val = -0.053 | conf = (0.000, 0.000)
#         (4 -2): pval = 0.01362 | val = 0.045 | conf = (0.000, 0.000)
#
#     Variable 3 has 12 link(s):
#         (1 0): pval = 0.00000 | val = -0.587 | conf = (0.000, 0.000)
#         (0 0): pval = 0.00000 | val = -0.560 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = -0.460 | conf = (0.000, 0.000)
#         (4 0): pval = 0.00000 | val = -0.387 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = 0.384 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = -0.271 | conf = (0.000, 0.000)
#         (1 -1): pval = 0.00000 | val = -0.234 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = 0.101 | conf = (0.000, 0.000)
#         (3 -2): pval = 0.00000 | val = -0.098 | conf = (0.000, 0.000)
#         (1 -2): pval = 0.00002 | val = -0.077 | conf = (0.000, 0.000)
#         (0 -2): pval = 0.00006 | val = 0.073 | conf = (0.000, 0.000)
#         (0 -1): pval = 0.01126 | val = 0.046 | conf = (0.000, 0.000)
#
#     Variable 4 has 14 link(s):
#         (1 -1): pval = 0.00000 | val = -0.668 | conf = (0.000, 0.000)
#         (3 -1): pval = 0.00000 | val = 0.576 | conf = (0.000, 0.000)
#         (0 0): pval = 0.00000 | val = 0.470 | conf = (0.000, 0.000)
#         (1 0): pval = 0.00000 | val = 0.454 | conf = (0.000, 0.000)
#         (3 0): pval = 0.00000 | val = -0.387 | conf = (0.000, 0.000)
#         (4 -1): pval = 0.00000 | val = 0.366 | conf = (0.000, 0.000)
#         (2 -1): pval = 0.00000 | val = -0.286 | conf = (0.000, 0.000)
#         (1 -2): pval = 0.00000 | val = -0.264 | conf = (0.000, 0.000)
#         (3 -2): pval = 0.00000 | val = 0.259 | conf = (0.000, 0.000)
#         (2 0): pval = 0.00000 | val = -0.240 | conf = (0.000, 0.000)
#         (0 -2): pval = 0.00000 | val = -0.238 | conf = (0.000, 0.000)
#         (4 -2): pval = 0.00000 | val = 0.210 | conf = (0.000, 0.000)
#         (0 -1): pval = 0.00000 | val = -0.107 | conf = (0.000, 0.000)
#         (2 -2): pval = 0.00029 | val = 0.066 | conf = (0.000, 0.000)
#
# ## Significant links at alpha = 0.01:
#
#     Variable 0 has 13 link(s):
#         (1 0): pval = 0.00000 | val = 0.697
#         (3 0): pval = 0.00000 | val = -0.560
#         (4 0): pval = 0.00000 | val = 0.470
#         (1 -1): pval = 0.00000 | val = -0.429
#         (2 -1): pval = 0.00000 | val = -0.348
#         (2 0): pval = 0.00000 | val = 0.246
#         (0 -1): pval = 0.00000 | val = -0.183
#         (3 -1): pval = 0.00000 | val = 0.153
#         (1 -2): pval = 0.00000 | val = -0.123
#         (3 -2): pval = 0.00008 | val = 0.072
#         (4 -1): pval = 0.00042 | val = 0.064
#         (0 -2): pval = 0.00279 | val = -0.055
#         (2 -2): pval = 0.00378 | val = 0.053
#
#     Variable 1 has 9 link(s):
#         (0 0): pval = 0.00000 | val = 0.697
#         (3 0): pval = 0.00000 | val = -0.587
#         (3 -1): pval = 0.00000 | val = 0.541
#         (4 0): pval = 0.00000 | val = 0.454
#         (0 -1): pval = 0.00000 | val = -0.361
#         (4 -1): pval = 0.00000 | val = 0.318
#         (2 -1): pval = 0.00000 | val = -0.195
#         (2 0): pval = 0.00000 | val = 0.103
#         (1 -1): pval = 0.00202 | val = 0.056
#
#     Variable 2 has 12 link(s):
#         (0 -1): pval = 0.00000 | val = -0.490
#         (3 -1): pval = 0.00000 | val = -0.393
#         (1 -1): pval = 0.00000 | val = 0.266
#         (0 0): pval = 0.00000 | val = 0.246
#         (4 0): pval = 0.00000 | val = -0.240
#         (4 -1): pval = 0.00000 | val = 0.140
#         (1 -2): pval = 0.00000 | val = -0.117
#         (1 0): pval = 0.00000 | val = 0.103
#         (3 0): pval = 0.00000 | val = 0.101
#         (2 -1): pval = 0.00010 | val = -0.071
#         (3 -2): pval = 0.00164 | val = 0.058
#         (0 -2): pval = 0.00386 | val = -0.053
#
#     Variable 3 has 11 link(s):
#         (1 0): pval = 0.00000 | val = -0.587
#         (0 0): pval = 0.00000 | val = -0.560
#         (3 -1): pval = 0.00000 | val = -0.460
#         (4 0): pval = 0.00000 | val = -0.387
#         (2 -1): pval = 0.00000 | val = 0.384
#         (4 -1): pval = 0.00000 | val = -0.271
#         (1 -1): pval = 0.00000 | val = -0.234
#         (2 0): pval = 0.00000 | val = 0.101
#         (3 -2): pval = 0.00000 | val = -0.098
#         (1 -2): pval = 0.00002 | val = -0.077
#         (0 -2): pval = 0.00006 | val = 0.073
#
#     Variable 4 has 14 link(s):
#         (1 -1): pval = 0.00000 | val = -0.668
#         (3 -1): pval = 0.00000 | val = 0.576
#         (0 0): pval = 0.00000 | val = 0.470
#         (1 0): pval = 0.00000 | val = 0.454
#         (3 0): pval = 0.00000 | val = -0.387
#         (4 -1): pval = 0.00000 | val = 0.366
#         (2 -1): pval = 0.00000 | val = -0.286
#         (1 -2): pval = 0.00000 | val = -0.264
#         (3 -2): pval = 0.00000 | val = 0.259
#         (2 0): pval = 0.00000 | val = -0.240
#         (0 -2): pval = 0.00000 | val = -0.238
#         (4 -2): pval = 0.00000 | val = 0.210
#         (0 -1): pval = 0.00000 | val = -0.107
#         (2 -2): pval = 0.00029 | val = 0.066
#
# ##
# ## Running Tigramite PC algorithm
# ##
#
# Parameters:
# independence test = par_corr
# tau_min = 1
# tau_max = 2
# pc_alpha = 0.2
# max_conds_dim = None
# max_combinations = 1
#
#
#
# ## Variable 0
#
# ## Variable 1
#
# ## Variable 2
#
# ## Variable 3
#
# ## Variable 4
#
# ## Resulting condition sets:
#
#     Variable 0 has 6 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.559
#         (1 -1): max_pval = 0.00000, min_val = 0.117
#         (2 -1): max_pval = 0.00000, min_val = 0.094
#         (4 -1): max_pval = 0.00000, min_val = 0.084
#         (0 -1): max_pval = 0.00172, min_val = 0.057
#         (0 -2): max_pval = 0.14296, min_val = 0.027
#
#     Variable 1 has 4 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.658
#         (4 -1): max_pval = 0.00000, min_val = 0.168
#         (2 -1): max_pval = 0.00000, min_val = 0.097
#         (1 -1): max_pval = 0.00001, min_val = 0.082
#
#     Variable 2 has 7 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.532
#         (4 -2): max_pval = 0.00000, min_val = 0.090
#         (1 -1): max_pval = 0.00280, min_val = 0.055
#         (2 -2): max_pval = 0.01535, min_val = 0.044
#         (0 -1): max_pval = 0.01737, min_val = 0.043
#         (4 -1): max_pval = 0.11159, min_val = 0.029
#         (0 -2): max_pval = 0.18558, min_val = 0.024
#
#     Variable 3 has 6 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.394
#         (4 -2): max_pval = 0.00000, min_val = 0.286
#         (2 -2): max_pval = 0.00000, min_val = 0.164
#         (0 -1): max_pval = 0.00000, min_val = 0.102
#         (3 -2): max_pval = 0.00000, min_val = 0.085
#         (1 -2): max_pval = 0.00296, min_val = 0.054
#
#     Variable 4 has 3 parent(s):
#         (3 -1): max_pval = 0.00000, min_val = 0.574
#         (2 -1): max_pval = 0.00888, min_val = 0.048
#         (2 -2): max_pval = 0.05837, min_val = 0.035
#
# ##
# ## Running Tigramite MCI algorithm
# ##
#
# Parameters:
#
# independence test = par_corr
# tau_min = 0
# tau_max = 2
# max_conds_py = None
# max_conds_px = None
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[8], line 32
#      27 parcorr = ParCorr()
#      28 pcmci_parcorr = PCMCI(
#      29 dataframe=dataframe,
#      30 cond_ind_test=parcorr,
#      31 verbosity=1)
# ---> 32 results = pcmci_parcorr.run_pcmci(tau_max=2, pc_alpha=0.2)
#      33 pcmci_parcorr.print_significant_links(
#      34 p_matrix = results['p_matrix'],
#      35     val_matrix = results['val_matrix'],
#      36     alpha_level = 0.01)
#      37 link_matrix = pcmci_parcorr.return_significant_parents(pq_matrix=results['p_matrix'],
#      38                     val_matrix=results['val_matrix'], alpha_level=0.01)['link_matrix']
#
# File ~/TECDI/baseline/PCMCI/tigramite/tigramite/pcmci.py:1766, in PCMCI.run_pcmci(self, selected_links, tau_min, tau_max, save_iterations, pc_alpha, max_conds_dim, max_combinations, max_conds_py, max_conds_px, fdr_method)
#    1758 all_parents = self.run_pc_stable(selected_links=selected_links,
#    1759                                  tau_min=tau_min,
#    1760                                  tau_max=tau_max,
#    (...)
#    1763                                  max_conds_dim=max_conds_dim,
#    1764                                  max_combinations=max_combinations)
#    1765 # Get the results from run_mci, using the parents as the input
# -> 1766 results = self.run_mci(selected_links=selected_links,
#    1767                        tau_min=tau_min,
#    1768                        tau_max=tau_max,
#    1769                        parents=all_parents,
#    1770                        max_conds_py=max_conds_py,
#    1771                        max_conds_px=max_conds_px)
#    1772 # Get the values and p-values
#    1773 val_matrix = results['val_matrix']
#
# File ~/TECDI/baseline/PCMCI/tigramite/tigramite/pcmci.py:1274, in PCMCI.run_mci(self, selected_links, tau_min, tau_max, parents, max_conds_py, max_conds_px)
#    1272 Y = [(j, 0)]
#    1273 # Run the independence tests and record the results
# -> 1274 val, pval = self.cond_ind_test.run_test(X, Y, Z=Z, tau_max=tau_max)
#    1275 val_matrix[i, j, abs(tau)] = val
#    1276 p_matrix[i, j, abs(tau)] = pval
#
# File ~/TECDI/baseline/PCMCI/tigramite/tigramite/independence_tests.py:343, in CondIndTest.run_test(self, X, Y, Z, tau_max, cut_off)
#     341     raise ValueError("nans in the array!")
#     342 # Get the dependence measure, reycling residuals if need be
# --> 343 val = self._get_dependence_measure_recycle(X, Y, Z, xyz, array)
#     344 # Get the p-value
#     345 pval = self.get_significance(val, array, xyz, T, dim)
#
# File ~/TECDI/baseline/PCMCI/tigramite/tigramite/independence_tests.py:439, in CondIndTest._get_dependence_measure_recycle(self, X, Y, Z, xyz, array)
#     437     return self.get_dependence_measure(array_resid, xyz_resid)
#     438 # If not, return the dependence measure on the array and xyz
# --> 439 return self.get_dependence_measure(array, xyz)
#
# File ~/TECDI/baseline/PCMCI/tigramite/tigramite/independence_tests.py:1104, in ParCorr.get_dependence_measure(self, array, xyz)
#    1084 def get_dependence_measure(self, array, xyz):
#    1085     """Return partial correlation.
#    1086
#    1087     Estimated as the Pearson correlation of the residuals of a linear
#    (...)
#    1101         Partial correlation coefficient.
#    1102     """
# -> 1104     x_vals = self._get_single_residuals(array, target_var=0)
#    1105     y_vals = self._get_single_residuals(array, target_var=1)
#    1106     val, _ = stats.pearsonr(x_vals, y_vals)
#
# File ~/TECDI/baseline/PCMCI/tigramite/tigramite/independence_tests.py:1074, in ParCorr._get_single_residuals(self, array, target_var, standardize, return_means)
#    1072     z = np.fastCopyAndTranspose(array[2:, :])
#    1073     beta_hat = np.linalg.lstsq(z, y, rcond=None)[0]
# -> 1074     mean = np.dot(z, beta_hat)
#    1075     resid = y - mean
#    1076 else:
#
# File <__array_function__ internals>:180, in dot(*args, **kwargs)
#
# KeyboardInterrupt:
